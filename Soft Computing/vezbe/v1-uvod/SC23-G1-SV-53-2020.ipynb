# %%
import numpy as np
import cv2 # OpenCV biblioteka
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = 16,12

# %%
img = cv2.cvtColor(cv2.imread('pictures/ditto_v1_notebook.jpg'), cv2.COLOR_BGR2RGB) # ucitavanje slike sa diska
plt.imshow(img)
